# %% [markdown]
# IDEALISTA

# %%
import requests
from bs4 import BeautifulSoup as bs
import random
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import undetected_chromedriver as uc

# %% [markdown]
# URL del piso

# %%
browser = uc.Chrome()

# %% [markdown]
# Bien!
#
# Ahora, vayamos a una casa que queramos scrapear. Yo he seleccionado esta, pero pon la que prefieras.

# %%
url = "https://www.idealista.com/inmueble/103344400/"

# %% [markdown]
# Vayamos a esa casa

# %%
browser.get(url)

# %% [markdown]
# Vaya, hay que pulsar las cookies! No puedes hacer click en nada de la información hasta que no la pulses.
#
# No te preocupes, buscamos el xpath como en el video y hacemos click en él.
#
# (También puedes hacer click manualmente. Nadie se va a enterar)

# %%
browser.find_element("xpath",'//*[@id="didomi-notice-agree-button"]').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 browser.find_element("xpath",'//*[@id="didomi-notice-agree-button"]').click()
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:770, in WebDriver.find_element(self, by, value)
#     767         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     768     return elements[0]
# --> 770 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:384, in WebDriver.execute(self, driver_command, params)
#     382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
# --> 384     self.error_handler.check_response(response)
#     385     response["value"] = self._unwrap_value(response.get("value", None))
#     386     return response
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="didomi-notice-agree-button"]"}
#   (Session info: chrome=131.0.6778.86); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00E033E3+25059]
# 	(No symbol) [0x00D8CDE4]
# 	(No symbol) [0x00C6BEC3]
# 	(No symbol) [0x00CAFD86]
# 	(No symbol) [0x00CAFFCB]
# 	(No symbol) [0x00CED952]
# 	(No symbol) [0x00CD1F44]
# 	(No symbol) [0x00CEB51E]
# 	(No symbol) [0x00CD1C96]
# 	(No symbol) [0x00CA3FAC]
# 	(No symbol) [0x00CA4F3D]
# 	GetHandleVerifier [0x010F5543+3113795]
# 	GetHandleVerifier [0x0110A20A+3198986]
# 	GetHandleVerifier [0x011029E2+3168226]
# 	GetHandleVerifier [0x00EA3250+680016]
# 	(No symbol) [0x00D9572D]
# 	(No symbol) [0x00D929D8]
# 	(No symbol) [0x00D92B75]
# 	(No symbol) [0x00D857D0]
# 	BaseThreadInitThunk [0x767B5D49+25]
# 	RtlInitializeExceptionChain [0x77BFCEBB+107]
# 	RtlGetAppContainerNamedObjectPath [0x77BFCE41+561]

# %% [markdown]
# Ahora, vamos a sacar el html de la página.

# %%
html = browser.page_source
html
# Out:
# '<html lang="es" env="es" username="" data-userauth="false" class=""><head>\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title>Ático en venta en paseo de l\'Albereda, Mestalla, València — idealista</title>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<meta name="description" content="Ático de 680 m², Ático en venta en paseo de l\'Albereda, Mestalla, València, barrio Mestalla">\n<meta name="author" content="idealista.com">\n<meta http-equiv="cleartype" content="on">\n<meta name="pragma" content="no-cache">\n<meta http-equiv="Pragma" content="no-cache">\n<meta http-equiv="Expires" content="Fri, 01 Jan 1990 00:00:00 GMT">\n<meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate">\n<link rel="shortcut icon" href="https://st3.idealista.com/static/common/icons/favicon.ico?20241129-1307">\n<link rel="apple-touch-icon" sizes="32x32" href="https://st3.idealista.com/static/common/icons/32x32.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" href="https://st3.idealista.com/static/common/icons/32x32.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="57x57" href="https://st3.idealista.com/static/common/icons/57x57.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" href="https://st3.idealista.com/static/common/icons/57x57.png?20241129-1307">\n<link rel="apple-touch-icon" href="https://st3.idealista.com/static/common/icons/60x60.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" href="https://st3.idealista.com/static/common/icons/60x60.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="76x76" href="https://st3.idealista.com/static/common/icons/76x76.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" sizes="76x76" href="https://st3.idealista.com/static/common/icons/76x76.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="96x96" href="https://st3.idealista.com/static/common/icons/96x96.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" href="https://st3.idealista.com/static/common/icons/96x96.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="120x120" href="https://st3.idealista.com/static/common/icons/120x120.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" sizes="120x120" href="https://st3.idealista.com/static/common/icons/120x120.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="128x128" href="https://st3.idealista.com/static/common/icons/128x128.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" href="https://st3.idealista.com/static/common/icons/128x128.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="144x144" href="https://st3.idealista.com/static/common/icons/144x144.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" href="https://st3.idealista.com/static/common/icons/144x144.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="152x152" href="https://st3.idealista.com/static/common/icons/152x152.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://st3.idealista.com/static/common/icons/152x152.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="167x167" href="https://st3.idealista.com/static/common/icons/167x167.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" href="https://st3.idealista.com/static/common/icons/167x167.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="180x180" href="https://st3.idealista.com/static/common/icons/180x180.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" href="https://st3.idealista.com/static/common/icons/180x180.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="192x192" href="https://st3.idealista.com/static/common/icons/192x192.png?20241129-1307">\n<link rel="apple-touch-icon-precomposed" href="https://st3.idealista.com/static/common/icons/192x192.png?20241129-1307">\n<link rel="apple-touch-icon" sizes="195x195" href="https://st3.idealista.com/static/common/icons/195x195.png?20241129-1307">\n<link rel="apple-touch-icon-precom ...

# %% [markdown]
# Que feo queda no?
#
# Vamos a usar BeautifulSoup para dejarlo mucho mejor. Y apto para sacar info.

# %%
soup = bs(html, 'lxml')
soup
# Out:
# <html class="" data-userauth="false" env="es" lang="es" username=""><head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Ático en venta en paseo de l'Albereda, Mestalla, València — idealista</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Ático de 680 m², Ático en venta en paseo de l'Albereda, Mestalla, València, barrio Mestalla" name="description"/>
# <meta content="idealista.com" name="author"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="no-cache" name="pragma"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Fri, 01 Jan 1990 00:00:00 GMT" http-equiv="Expires"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <link href="https://st3.idealista.com/static/common/icons/favicon.ico?20241129-1307" rel="shortcut icon"/>
# <link href="https://st3.idealista.com/static/common/icons/32x32.png?20241129-1307" rel="apple-touch-icon" sizes="32x32"/>
# <link href="https://st3.idealista.com/static/common/icons/32x32.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/57x57.png?20241129-1307" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://st3.idealista.com/static/common/icons/57x57.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/60x60.png?20241129-1307" rel="apple-touch-icon"/>
# <link href="https://st3.idealista.com/static/common/icons/60x60.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/76x76.png?20241129-1307" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://st3.idealista.com/static/common/icons/76x76.png?20241129-1307" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://st3.idealista.com/static/common/icons/96x96.png?20241129-1307" rel="apple-touch-icon" sizes="96x96"/>
# <link href="https://st3.idealista.com/static/common/icons/96x96.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/120x120.png?20241129-1307" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://st3.idealista.com/static/common/icons/120x120.png?20241129-1307" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://st3.idealista.com/static/common/icons/128x128.png?20241129-1307" rel="apple-touch-icon" sizes="128x128"/>
# <link href="https://st3.idealista.com/static/common/icons/128x128.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/144x144.png?20241129-1307" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://st3.idealista.com/static/common/icons/144x144.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/152x152.png?20241129-1307" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://st3.idealista.com/static/common/icons/152x152.png?20241129-1307" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://st3.idealista.com/static/common/icons/167x167.png?20241129-1307" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://st3.idealista.com/static/common/icons/167x167.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/180x180.png?20241129-1307" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://st3.idealista.com/static/common/icons/180x180.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/192x192.png?20241129-1307" rel="apple-touch-icon" sizes="192x192"/>
# <link href="https://st3.idealista.com/static/common/icons/192x192.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/195x195.png?20241129-1307" rel="apple-touch-icon" sizes="195x195"/>
# <link href="https://st3.idealista.com/static/common/icons/195x195.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <link href="https://st3.idealista.com/static/common/icons/196x196.png?20241129-1307" rel="apple-touch-icon" sizes="196x196"/>
# <link href="https://st3.idealista.com/static/common/icons/196x196.png?20241129-1307" rel="apple-touch-icon-precomposed"/>
# <script async="" charset="utf-8" id="utag_244" src="https://cdn.taboola.com/libtrc/unip/1420147/tfa.js" type="text/javascript"></script><script async="" charset="utf-8" id="utag_228" src="//amplify.outbrain.com/cp/obtp.js" type="text/javascript"></script><script async="" charset="utf-8" id="utag_195" src="https://tags.creativecdn.com/wCBrfTqZpg4dW1fLt8FZ.js" type="text/javascript"></script><script async="" charset="utf-8" id="utag_192" src="https://dynamic.criteo.com/js/ld/ld.js?a=13122&amp;a=19089&amp;a=31531" type="text/javascript"></script><script async="" src="https://dd.idealista.com/tags.js"></script><script async="" charset="utf-8" id="utag_154" src="https://www.googletagmanager.com/gtag/js?id=AW-1061695190" type="text/javascript"></script><script async="" charset="utf-8" id="utag_239" src="https://tag.aticdn.net/piano-analytics.js" type="text/javascript"></script><script defer="" src="//dp.idealista.com/es-portal/prod/utag.js" type="text/javascript"></script><script async="" charset="utf-8" id="spcloader" src="https://sdk.privacy-center.org/645b65e6-0665-4634-b4e4-98e7024b6598/loader.js?target=www.idealista.com" type="text/javascript"></script><script defer="" src="https://st3.idealista.com/static/common/js/lib/jquery/jquery-1.12.4.js?20241129-1307"></script>
# <script defer="" src="https://st3.idealista.com/static/common/js/lib/jquery/jquery-migrate-1.4.1.js?20241129-1307"></script>
# <script defer="" src="https://st3.idealista.com/static/common/js/lib/jquery/jquery-nr.js?20241129-1307"></script>
# <script defer="" src="https://st3.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-consent-lang.js"></script>
# <script defer="" src="https://st3.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-iab-integration.js"></script>
# <script defer="" src="https://st3.idealista.com/static/common/release/mavericks/legacy/js/didomi/didomi-embed.js"></script>
# <script async="" charset="utf-8" data-vendor="c:abtasty-LLkECCj8" src="//try.abtasty.com/ba99abce363c777e429f2eef6f87c927.js" type="text/javascript"></script><script async="" charset="utf-8" data-processed="true" data-vendor="c:abtasty-LLkECCj8" src="//try.abtasty.com/ba99abce363c777e429f2eef6f87c927.js" type="didomi/javascript"></script>
# <script>
# 			var isABTastyActive = true;
# 		</script>
# <link as="style" href="https://st3.idealista.com/static/common/css/lib/icons/iconfont-old-minify.css?20241129-1307" rel="preload"/>
# <link href="https://st3.idealista.com/static/common/css/lib/icons/iconfont-old-minify.css?20241129-1307" rel="stylesheet" type="text/css"/>
# <link as="style" href="https://st3.idealista.com/static/common/release/detail/detail.css?20241129-1307" rel="preload"/>
# <link href="https://st3.idealista.com/static/common/release/detail/detail.css?20241129-1307" rel="stylesheet" type="text/css"/>
# <link as="style" href="https://st3.idealista.com/static/common/release/modules/auction-valuation-modal.css?20241129-1307" rel="preload"/>
# <link href="https://st3.idealista.com/static/common/release/modules/auction-valuation-modal.css?20241129-1307" rel="stylesheet" type="text/css"/>
# <link as="style" href="https://st3.idealista.com/static/common/release/contact/contact-manager.css?20241129-1307" rel="preload"/>
# <link href="https://st3.idealista.com/static/common/release/contact/contact-manager.css?20241129-1307" rel="stylesheet" type="text/css"/>
# <link as="style" href="https://st3.idealista.com/static/common/release/modules/gallery-widget.css?20241129-1307" rel="preload"/>
# <link href="https://st3.idealista.com/static/common/release/modules/gallery-widget.css?20241129-1307" rel="stylesheet" type="text/css"/>
# <link href="https://st3.idealista.com/static/common/release/modules/agency-video-player.css?20241129-1307" rel="stylesheet" type="text/css"/>
# <link href="https://st3.idealista.com/static/react/projects/loginAndRegister/dist/LoginInPlace.css?20241129-1307" rel="stylesheet" type="text/css"/>
# <link as="style" href="https://st1.idealista.com/mortgages/static/release/IdForm/es/ad_detail/main.css?20241129-1307" onload="this.onload=null;this.rel='stylesheet'" rel="stylesheet"/>
# <noscript><link href="https://st1.idealista.com/mortgages/static/release/IdForm/es/ad_detail/main.css?20241129-1307" rel="stylesheet"/></noscript>
# <link href="https://www.idealista.com/inmueble/103344400/" rel="canonical"/>
# <meta content="noodp,index, follow" name="robots"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0" name="viewport"/>
# <meta content="https://img4.idealista.com/blur/WEB_DETAIL-M-L/0/id.pro.es.image.master/34/f6/1e/1214271427.jpg" property="og:image"/>
# <meta content="1500" property="og:image:width"/>
# <meta content="1000" property="og:image:height"/>
# <script>
#     document.addEventListener("DOMContentLoaded", function () {
#         var isMobile = window.matchMedia("(max-width: 48rem)").matches;
#         var advertisementScriptsContentDiv = document.getElementById("advertisementScriptsContent");
#         if (advertisementScriptsContentDiv) {
#             fetch('/showAdvertisementScriptsContent?isMobile=' + isMobile)
#                 .then(response => response.text())
#                 .then(data => {
#                     if (data === "true") {
#                         advertisementScriptsContentDiv.style.display = 'block';
#                     } else {
#                         advertisementScriptsContentDiv.style.display = 'none';
#                     }
#                 })
#                 .catch(error => console.error('Error..... showAdvertisementScriptsContent: ', error));
#         }
#     });
# </script>
# <link href="https://st3.idealista.com/static/react/projects/detail/dist/async-galleryDetail_el-properties.21a7493a39f74d1e5466.css" media="all" rel="stylesheet" type="text/css"/><script async="" charset="utf-8" src="https://sdk.privacy-center.org/sdk/46aa9a6b2e416522b487b87711d9584ac1ebaeab/modern/sdk.46aa9a6b2e416522b487b87711d9584ac1ebaeab.js" type="text/javascript"></script><link href="https://st3.idealista.com/static/react/projects/detail/dist/async-galleryDetail_ca-properties.21a7493a39f74d1e5466.css" rel="stylesheet" type="text/css"/><link href="https://st3.idealista.com/static/react/projects/detail/dist/816.21a7493a39f74d1e5466.css" rel="stylesheet" type="text/css"/><style>:root{--font-family-default: Bernino Sans;--line-height-small: 1.375;--line-height-medium: 1.5;--font-weight-regular: 400;--font-weight-semibold: 500;--font-weight-bold: 600;--font-size-100: .75rem;--font-size-200: .875rem;--font-size-300: 1rem;--font-size-400: 1.125rem;--font-size-500: 1.25rem;--font-size-600: 1.375rem;--font-size-700: 1.5rem;--font-size-800: 1.75rem;--font-size-900: 2rem;--letter-spacing-small: -.2%}.kiwi-text__start{text-align:start}.kiwi-text__center{text-align:center}.kiwi-text__end{text-align:end}.kiwi-text__bold{font-weight:var(--font-weight-bold)}.kiwi-text__semibold{font-weight:var(--font-weight-semibold)}.kiwi-text__regular{font-weight:var(--font-weight-regular)}.kiwi-text__clamp-1,.kiwi-text__clamp-2,.kiwi-text__clamp-3,.kiwi-text__clamp-4,.kiwi-text__clamp-5{display:-webkit-box;-webkit-box-orient:vertical;overflow:hidden}.kiwi-text__clamp-1{-webkit-line-clamp:1}.kiwi-text__clamp-2{-webkit-line-clamp:2}.kiwi-text__clamp-3{-webkit-line-clamp:3}.kiwi-text__clamp-4{-webkit-line-clamp:4}.kiwi-text__clamp-5{-webkit-line-clamp:5}.kiwi-text--visually-hidden{position:absolute!important;top:0;width:1px!important;height:1px!important;margin:0!important;padding:0!important;overflow:hidden!important;clip-path:inset(50%)!important;border:0!important;white-space:nowrap!important}.kiwi-headline__xl{font-size:var(--fluid-font-size-xl);letter-spacing:var(--letter-spacing-small);line-height:var(--line-height-small)}.kiwi-headline__l{font-size:var(--fluid-font-size-l);letter-spacing:var(--letter-spacing-small);line-height:var(--line-height-small)}.kiwi-headline__m{font-size:var(--fluid-font-size-m);letter-spacing:var(--letter-spacing-small);line-height:var(--line-height-small)}.kiwi-headline__s{font-size:var(--font-size-500);letter-spacing:0}.kiwi-text__label{font-size:var(--font-size-100);letter-spacing:0}.kiwi-body__l{font-size:var(--font-size-400);letter-spacing:0}.kiwi-body__m{font-size:var(--font-size-300);letter-spacing:0}.kiwi-body__s{font-size:var(--font-size-200);letter-spacing:0}:root{--elevation-01: 0 .0625rem .125rem 0 #6f6f6d3d;--elevation-02: 0 .125rem .5rem 0 #6f6f6d3d;--elevation-03: 0 .25rem 1rem 0 #6f6f6d52;--elevation-04: 0 .5rem 2rem 0 #6f6f6d66;--dimension-x025: .0625rem;--dimension-x050: .125rem;--dimension-x100: .25rem;--dimension-x150: .375rem;--dimension-x200: .5rem;--dimension-x250: .625rem;--dimension-x300: .75rem;--dimension-x350: .875rem;--dimension-x400: 1rem;--dimension-x450: 1.125rem;--dimension-x500: 1.25rem;--dimension-x550: 1.375rem;--dimension-x600: 1.5rem;--dimension-x700: 1.75rem;--dimension-x800: 2rem;--dimension-x900: 2.25rem;--dimension-x1000: 2.5rem;--dimension-x1100: 2.75rem;--dimension-x1200: 3rem;--dimension-x1400: 3.5rem;--dimension-x1500: 3.75rem;--dimension-x1600: 4rem;--dimension-x1800: 4.5rem;--dimension-x2000: 5rem;--dimension-x2400: 6rem;--border-radius-small: .125rem;--border-radius-medium: .25rem;--border-radius-full: 6rem;--border-width-small: .0625rem;--border-width-medium: .125rem;--border-width-large: .25rem;--opacity-0: 0;--opacity-25: .25;--opacity-50: .5;--opacity-75: .75;--opacity-100: 1;--size-icon-medium: 1.25rem;--size-icon-large: 1.5rem;--height-interactive-small: 2rem;--height-interactive-medium: 2.5rem;--height-interactive-large: 3rem;--width-min-medium: 5rem;--width-interact ...
#   display: flex;
#   align-items: flex-start;
#   padding: var(--padding-small);
#   font-size: var(--font-size-body-m);
#   border-radius: var(--border-radius-01);
# }
# .favorite-lists-selector-feedback.--success,
# .favorite-lists-selector-feedback.--info {
#   color: var(--core-extension-color-content-positive);
#   background-color: var(--core-extension-color-background-positive-light);
# }
# .favorite-lists-selector-feedback.--warning {
#   color: var(--core-extension-color-content-info);
#   background-color: var(--core-extension-color-background-info-light);
# }
# .favorite-lists-selector-feedback.--warning [class*="icon-"]::before {
#   color: var(--core-extension-color-content-info);
# }
# .favorite-lists-selector-feedback.--error {
#   color: var(--color-red-50);
#   background-color: var(--color-negative-10);
# }
# .favorite-lists-selector-feedback.--error p {
#   color: initial;
# }
# .favorite-lists-selector-feedback__header {
#   display: flex;
#   flex-direction: column;
# }
# .favorite-lists-selector-feedback__title {
#   font-weight: var(--font-weight-regular);
#   font-size: var(--font-size-400);
#   margin-bottom: 0;
#   padding-top: 0;
# }
# .favorite-lists-selector-feedback__icon {
#   margin-right: var(--padding-x-small);
# }
#
# .favorite-lists-selector-feedback.--notification {
#   position: relative;
#   top: 0;
#   margin: 1rem 0;
#   left: 50%;
#   transform: translate(-50%, 0);
#   padding: var(--gap-large);
#   cursor: pointer;
#   border-radius: 4px;
#   box-shadow: var(--elevation-02);
# }
# .favorite-lists-selector-feedback.--notification p {
#   margin-bottom: 0;
# }
# .favorite-lists-selector-feedback.--notification.--toast {
#   position: fixed;
#   top: 5rem;
#   margin: 0;
#   text-align: left;
#   align-items: center;
#   max-width: 40rem;
#   width: auto;
#   z-index: 20;
# }
# @media screen and (max-width: 48rem) {
#   .favorite-lists-selector-feedback.--notification.--toast {
#     width: 100%;
#     max-width: calc(100% - 1rem * 2);
#   }
# }
# .favorite-lists-selector-feedback.--notification.--toast.--error {
#   align-items: flex-start;
# }
# .favorite-lists-selector-feedback.--notification.--restore {
#   width: 100%;
#   justify-content: flex-start;
#   align-items: center;
#   margin-top: 0;
# }
# .favorite-lists-selector-feedback.--notification.--restore:not(.--toast) {
#   max-width: unset;
# }
# .favorite-lists-selector-feedback.--notification.--restore .favorite-lists-selector-feedback__info {
#   flex-direction: row;
#   align-items: center;
#   gap: var(--gap-small);
#   width: 100%;
# }
# @media screen and (max-width: 48rem) {
#   .favorite-lists-selector-feedback.--notification.--restore {
#     margin-bottom: 2rem;
#     align-items: flex-start;
#   }
#   .favorite-lists-selector-feedback.--notification.--restore .favorite-lists-selector-feedback__info {
#     flex-direction: column;
#     align-items: flex-start;
#   }
#   .favorite-lists-selector-feedback.--notification.--restore .favorite-lists__feedback-undo {
#     width: 100%;
#   }
# }
# .favorite-lists-selector-feedback.--notification .favorite-lists-selector-feedback__info {
#   display: flex;
#   flex-direction: column;
#   align-items: flex-start;
# }
# .favorite-lists-selector-feedback.--notification .favorite-lists__feedback-undo {
#   display: flex;
#   align-items: center;
#   margin-left: auto;
#   padding: var(--gap-small) 0;
#   font-weight: var(--font-weight-bold);
#   gap: var(--gap-small);
# }
# .favorite-lists-selector-feedback.--notification .favorite-lists__feedback-undo::before {
#   color: var(--color-link-50);
# }
# .favorite-lists-selector-feedback.--notification .bold {
#   font-weight: var(--font-weight-bold);
# }
# .favorite-lists-selector-feedback.--notification__icon {
#   background-color: rgba(128, 128, 128, 0.16);
#   border-radius: var(--border-radius-01);
# }
# @media screen and (max-width: 48rem) {
#   .favorite-lists-selector-feedback.--notification {
#     top: 1rem;
#     width: 100%;
#     max-width: calc(100% - 1rem * 2);
#   }
# }
#
# .favorite-lists-menu__list {
#   display: flex;
#   flex-direction: column;
#   width: max-content;
#   position: absolute;
#   z-index: 11;
#   list-style: none;
#   padding: var(--gap-medium);
#   background-color: var(--core-color-background-primary);
#   box-shadow: var(--elevation-02);
#   border-radius: var(--border-radius-medium);
# }
# .favorite-lists-menu__item {
#   display: flex;
#   align-items: center;
#   width: 100%;
#   gap: var(--gap-medium);
#   padding: var(--padding-x-small);
#   font-weight: var(--font-weight-bold);
#   color: var(--color-link-50);
#   cursor: pointer;
#   text-align: left;
# }
# .favorite-lists-menu__item:hover {
#   background-color: var(--core-states-color-background-hover);
# }
# .favorite-lists-menu__item-move-title {
#   margin-bottom: 0.3rem;
#   line-height: normal;
# }
# .favorite-lists-menu__item-move-subtitle {
#   font-size: var(--font-size-200);
#   color: var(--core-color-content-secondary);
#   font-weight: var(--font-weight-regular);
#   line-height: normal;
# }
# .favorite-lists-menu__item [class*=icon-] {
#   display: flex;
#   align-items: center;
# }
# .favorite-lists-menu__item [class*=icon-]:before {
#   color: var(--color-link-50);
#   margin-right: var(--gap-small);
# }
#
# .rs-modal.opened .favorite-lists-modal.favorite-lists-modal {
#   position: fixed;
#   top: 50%;
#   left: 50%;
#   transform: translate(-50%, -50%);
#   margin: 0;
#   max-width: 34.5rem;
#   width: 100%;
#   z-index: 16;
# }
# .rs-modal.opened .favorite-lists-modal.favorite-lists-modal__title {
#   font-weight: var(--font-weight-bold);
#   line-height: var(--typography-headline-xl-line-height);
#   letter-spacing: -0.0125rem;
# }
# .rs-modal.opened .favorite-lists-modal.favorite-lists-modal .svg-close {
#   flex-grow: 0;
#   margin: 0;
# }
# .rs-modal.opened .favorite-lists-modal.favorite-lists-modal .svg-close::before {
#   content: '\e109';
#   background: none;
#   font-family: idealista-regular, Arial, sans-serif;
#   font-size: 1.5rem;
#   font-weight: 400;
#   line-height: normal;
#   speak: none;
#   text-transform: none;
#   vertical-align: middle;
#   font-smooth: antialiased;
#   -webkit-font-smoothing: antialiased;
#   -moz-osx-font-smoothing: grayscale;
# }
# .rs-modal.opened .favorite-lists-modal.favorite-lists-modal .favorite-lists__title {
#   font-size: var(--font-size-headline-xl);
# }
# .rs-modal.opened .favorite-lists-modal.favorite-lists-modal .rs-button:not(.favorite-lists-selector-back-button) {
#   width: 100%;
# }
# @media screen and (min-width: 48rem) {
#   .rs-modal.opened .favorite-lists-modal.favorite-lists-modal .rs-button:not(.favorite-lists-selector-back-button) {
#     width: auto;
#   }
# }
# @media screen and (max-width: 34rem) {
#   .rs-modal.opened .favorite-lists-modal.favorite-lists-modal {
#     top: unset;
#     left: 0;
#     bottom: 0;
#     transform: unset;
#   }
# }
#
# .favorite-lists-selector-title {
#   margin-bottom: var(--gap-large);
#   font-weight: var(--font-weight-bold);
#   font-size: var(--font-size-700);
# }
#
# .favorite-lists-selector-header {
#   color: var(--core-color-content-primary);
#   background-color: var(--color-white-00);
# }
# .favorite-lists-selector-header__subtitle {
#   font-weight: var(--font-weight-regular);
#   font-size: var(--font-size-300);
# }
#
# .favorite-lists-selector-lists-feedback {
#   margin-bottom: var(--gap-large);
# }
#
# .lists-feed {
#   list-style: none;
#   padding: 0;
# }
# .lists-feed .rs-checkbox {
#   margin-bottom: 1rem;
# }
#
# .create-list-form__fieldset {
#   display: flex;
#   flex-direction: column;
#   gap: var(--dimension-x200);
#   padding: 0 0 var(--dimension-x800) 0;
#   margin: 0;
# }
# .create-list-form__label {
#   color: var(--core-color-content-primary);
#   font-weight: var(--font-weight-bold);
# }
# .create-list-form__input.create-list-form__input {
#   display: flex;
#   padding: var(--gap-medium) var(--gap-large);
#   max-width: none;
#   align-items: flex-start;
#   gap: var(--dimension-x500);
#   align-self: stretch;
# }
# .create-list-form__input.create-list-form__input.validation-error {
#   border-color: var(--color-orange-40);
# }
# .create-list-form__info {
#   width: 100%;
#   display: flex;
#   align-items: center;
#   justify-content: space-between;
#   flex-direction: row-reverse;
# }
# .create-list-form__info .validation-error {
#   color: var(--color-orange-40);
# }
# .create-list-form .character-counter {
#   text-align: right;
# }
# .create-list-form .character-counter.--max-characters-warning {
#   color: var(--color-orange-40);
# }
#
# .create-list-form-skeleton .create-list-form-skeleton__button,
# .create-list-form-skeleton .create-list-form-skeleton__fieldset * {
#   display: block;
#   padding: 1rem;
#   background: linear-gradient(270deg, #FCFCFC 0%, #E5E6E1 104.64%);
#   animation: waves 2s infinite alternate;
# }
# .create-list-form-skeleton__fieldset {
#   display: flex;
#   flex-direction: column;
#   gap: 0.5rem;
#   padding: 0 0 var(--dimension-x800) 0;
#   margin: 0;
# }
# .create-list-form-skeleton__label {
#   width: 13rem;
#   height: 1.62rem;
# }
# .create-list-form-skeleton__character-counter {
#   width: 4rem;
#   height: 1.62rem;
#   align-self: flex-end;
# }
# .create-list-form-skeleton__button {
#   width: 9.5rem;
# }
# .create-list-form-skeleton__input {
#   height: 2.62rem;
# }
# @keyframes waves {
#   0% {
#     background: #E9E9E9 104.64%;
#   }
#   100% {
#     background: #FCFCFC 0%;
#   }
# }
#
# .favorite-lists-selector-back-button.rs-button.rs-button.rs-button {
#   width: auto;
#   font-size: var(--font-size-300);
#   margin: 0;
#   margin-top: calc(var(--gap-medium) * -1);
#   margin-left: calc(var(--gap-large) * -1);
#   text-decoration: none;
# }
# .favorite-lists-selector-back-button.rs-button.rs-button.rs-button span {
#   font-size: inherit;
# }
# .favorite-lists-selector-back-button.rs-button.rs-button.rs-button .button-cta__label:hover {
#   text-decoration: underline;
# }
# .favorite-lists-selector-back-button.rs-button.rs-button.rs-button .button-cta__icon {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
# .favorite-lists-selector-back-button.rs-button.rs-button.rs-button .button-cta__icon::before {
#   margin-right: var(--gap-small);
#   color: var(--color-link-50);
# }
# .favorite-lists-selector-back-button.rs-button.rs-button.rs-button .button-cta__icon:hover {
#   text-decoration: none;
# }
#
# .apply-development-mode {
#   font-family: var(--typography-body-s-regular-font-family), sans-serif;
# }
# .apply-development-mode input {
#   font-family: inherit;
# }
# .apply-development-mode * {
#   box-sizing: border-box;
# }
# .favorite-lists-container-modal .rs-modal.opened::before {
#   z-index: 15;
# }
# .favorite-lists-container-modal.--is-development {
#   font-family: var(--typography-body-s-regular-font-family), sans-serif;
# }
# .favorite-lists-container-modal.--is-development input {
#   font-family: inherit;
# }
# .favorite-lists-container-modal.--is-development * {
#   box-sizing: border-box;
# }
# @media screen and (max-width: 48rem) {
#   .favorite-lists-container-modal .rs-button {
#     width: 100%;
#   }
# }
# .favorite-lists-container-modal .rs-button.button-cta {
#   display: flex;
#   height: auto;
#   font-weight: var(--font-weight-bold);
#   margin-top: var(--dimension-x600);
# }
# .favorite-lists-container-modal .rs-button.button-cta__link {
#   margin-top: var(--dimension-x500);
#   padding-left: 0;
#   justify-content: left;
#   font-weight: var(--font-weight-bold);
# }
# .favorite-lists-container-modal .rs-button.button-cta__link .button-cta__icon {
#   display: flex;
#   align-items: center;
# }
# .favorite-lists-container-modal .rs-button.button-cta__link .button-cta__icon::before {
#   margin-right: var(--gap-small);
#   color: var(--color-link-50);
# }
# .favorite-lists-container-modal .rs-button.button-cta__link .button-cta__icon:hover {
#   text-decoration: none;
# }
# .favorite-lists-container-modal .rs-button.button-cta__link:not([disabled]):hover {
#   text-decoration: none;
# }
# .favorite-lists-container-modal .rs-button.button-cta__link:not([disabled]):hover .button-cta__label {
#   text-decoration: underline;
# }
#
# /**
#  * Do not edit directly
#  * Generated on Fri, 01 Dec 2023 08:41:52 GMT
#  */
# :root {
#   --elevation-01: 0 0.0625rem 0.125rem 0 #6f6f6d3d;
#   --elevation-02: 0 0.125rem 0.5rem 0 #6f6f6d3d;
#   --elevation-03: 0 0.25rem 1rem 0 #6f6f6d52;
#   --elevation-04: 0 0.5rem 2rem 0 #6f6f6d66;
#   --dimension-x025: 0.0625rem;
#   --dimension-x050: 0.125rem;
#   --dimension-x100: 0.25rem;
#   --dimension-x150: 0.375rem;
#   --dimension-x200: 0.5rem;
#   --dimension-x250: 0.625rem;
#   --dimension-x300: 0.75rem;
#   --dimension-x350: 0.875rem;
#   --dimension-x400: 1rem;
#   --dimension-x450: 1.125rem;
#   --dimension-x500: 1.25rem;
#   --dimension-x550: 1.375rem;
#   --dimension-x600: 1.5rem;
#   --dimension-x700: 1.75rem;
#   --dimension-x800: 2rem;
#   --dimension-x900: 2.25rem;
#   --dimension-x1000: 2.5rem;
#   --dimension-x1100: 2.75rem;
#   --dimension-x1200: 3rem;
#   --dimension-x1400: 3.5rem;
#   --dimension-x1500: 3.75rem;
#   --dimension-x1600: 4rem;
#   --dimension-x1800: 4.5rem;
#   --dimension-x2000: 5rem;
#   --dimension-x2400: 6rem;
#   --border-radius-small: 0.125rem;
#   --border-radius-medium: 0.25rem;
#   --border-radius-full: 6rem;
#   --border-width-small: 0.0625rem;
#   --border-width-medium: 0.125rem;
#   --border-width-large: 0.25rem;
#   --opacity-0: 0;
#   --opacity-25: 0.25;
#   --opacity-50: 0.5;
#   --opacity-75: 0.75;
#   --opacity-100: 1;
#   --size-icon-medium: 1.25rem;
#   --size-icon-large: 1.5rem;
#   --height-interactive-small: 2rem;
#   --height-interactive-medium: 2.5rem;
#   --height-interactive-large: 3rem;
#   --width-min-medium: 5rem;
#   --width-interactive-small: 2rem;
#   --width-interactive-medium: 2.5rem;
#   --width-interactive-large: 3rem;
#   --padding-x-small: 0.5rem;
#   --padding-small: 0.75rem;
#   --padding-medium: 1rem;
#   --padding-large: 1.5rem;
#   --gap-small: 0.25rem;
#   --gap-medium: 0.5rem;
#   --gap-large: 1rem;
# }
# /**
#  * Do not edit directly
#  * Generated on Fri, 01 Dec 2023 08:41:52 GMT
#  */
# :root {
#   --font-family-default: Bernino Sans;
#   --line-height-small: 1.375;
#   --line-height-medium: 1.5;
#   --font-weight-regular: 400;
#   --font-weight-semibold: 500;
#   --font-weight-bold: 600;
#   --font-size-100: 0.75rem;
#   --font-size-200: 0.875rem;
#   --font-size-300: 1rem;
#   --font-size-400: 1.125rem;
#   --font-size-500: 1.25rem;
#   --font-size-600: 1.375rem;
#   --font-size-700: 1.5rem;
#   --font-size-800: 1.75rem;
#   --font-size-900: 2rem;
#   --letter-spacing-small: -0.2%;
# }
# /**
#  * Do not edit directly
#  * Generated on Fri, 01 Dec 2023 08:41:52 GMT
#  */
# :root {
#   --color-grey-10: #f4f5f2;
#   --color-grey-20: #e5e6e1;
#   --color-grey-30: #cbccc7;
#   --color-grey-40: #a3a3a0;
#   --color-grey-50: #6f6f6d;
#   --color-grey-60: #4d4d4c;
#   --color-red-10: #fff0f0;
#   --color-red-20: #ffc7c2;
#   --color-red-30: #f55858;
#   --color-red-40: #d62f2f;
#   --color-red-50: #b81d29;
#   --color-red-60: #910f19;
#   --color-orange-10: #fff3e5;
#   --color-orange-20: #fad9b4;
#   --color-orange-30: #faa84b;
#   --color-orange-40: #e07901;
#   --color-orange-50: #ac5b06;
#   --color-orange-60: #7b4104;
#   --color-yellow-10: #fff8db;
#   --color-yellow-20: #faedaa;
#   --color-yellow-30: #ffdd57;
#   --color-yellow-40: #ebc11c;
#   --color-yellow-50: #ad8d0e;
#   --color-yellow-60: #806703;
#   --color-lime-10: #faffe0;
#   --color-lime-20: #edfca2;
#   --color-lime-30: #e1f56e;
#   --color-lime-40: #b1d004;
#   --color-lime-50: #839906;
#   --color-lime-60: #576600;
#   --color-green-10: #ebfaeb;
#   --color-green-20: #c5f0c5;
#   --color-green-30: #5ecc5e;
#   --color-green-40: #0c990c;
#   --color-green-50: #1d7a24;
#   --color-green-60: #075c13;
#   --color-teal-10: #edfcfc;
#   --color-teal-20: #c0f0ee;
#   --color-teal-30: #46c2be;
#   --color-teal-40: #069e99;
#   --color-teal-50: #05737a;
#   --color-teal-60: #004d5c;
#   --color-blue-10: #ebf4ff;
#   --color-blue-20: #d1e7ff;
#   --color-blue-30: #5ca8ff;
#   --color-blue-40: #1d84fa;
#   --color-blue-50: #145bc7;
#   --color-blue-60: #093a8f;
#   --color-purple-10: #f6f0ff;
#   --color-purple-20: #e4d1ff;
#   --color-purple-30: #b07ff5;
#   --color-purple-40: #7d48c7;
#   --color-purple-50: #582dad;
#   --color-purple-60: #2c117a;
#   --color-magenta-10: #fff0f9;
#   --color-magenta-20: #ffd1ee;
#   --color-magenta-30: #d158a5;
#   --color-magenta-40: #b62682;
#   --color-magenta-50: #8f156a;
#   --color-magenta-60: #660c51;
#   --color-white-00: #ffffff;
#   --color-black-00: #141414;
#   --color-mono-10: #f4f5f2;
#   --color-mono-20: #e5e6e1;
#   --color-mono-30: #cbccc7;
#   --color-mono-40: #a3a3a0;
#   --color-mono-50: #6f6f6d;
#   --color-mono-60: #4d4d4c;
#   --color-mono-100: #141414;
#   --color-mono-00: #ffffff;
#   --color-negative-10: #fff0f0;
#   --color-negative-20: #ffc7c2;
#   --color-negative-30: #f55858;
#   --color-negative-40: #d62f2f;
#   --color-negative-50: #b81d29;
#   --color-negative-60: #910f19;
#   --color-warning-10: #fff3e5;
#   --color-warning-20: #fad9b4;
#   --color-warning-30: #faa84b;
#   --color-warning-40: #e07901;
#   --color-warning-50: #ac5b06;
#   --color-warning-60: #7b4104;
#   --color-info-10: #fff8db;
#   --color-info-20: #faedaa;
#   --color-info-30: #ffdd57;
#   --color-info-40: #ebc11c;
#   --color-info-50: #ad8d0e;
#   --color-info-60: #806703;
#   --color-brand-10: #faffe0;
#   --color-brand-20: #edfca2;
#   --color-brand-30: #e1f56e;
#   --color-brand-40: #b1d004;
#   --color-brand-50: #839906;
#   --color-brand-60: #576600;
#   --color-positive-10: #ebfaeb;
#   --color-positive-20: #c5f0c5;
#   --color-positive-30: #5ecc5e;
#   --color-positive-40: #0c990c;
#   --color-positive-50: #1d7a24;
#   --color-positive-60: #075c13;
#   --color-accent-10: #fff0f9;
#   --color-accent-20: #ffd1ee;
#   --color-accent-30: #d158a5;
#   --color-accent-40: #b62682;
#   --color-accent-50: #8f156a;
#   --color-accent-60: #660c51;
#   --color-link-10: #ebf4ff;
#   --color-link-20: #d1e7ff;
#   --color-link-30: #5ca8ff;
#   --color-link-40: #1d84fa;
#   --color-link-50: #145bc7;
#   --color-link-60: #093a8f;
#   --core-color-content-primary: #141414;
#   --core-color-content-secondary: #6f6f6d;
#   --core-color-content-inverse: #ffffff;
#   --core-color-background-base: #f4f5f2;
#   --core-color-background-primary: #ffffff;
#   --core-color-background-secondary: #f4f5f2;
#   --core-color-background-inverse: #4d4d4c;
#   --core-color-background-overlay: #141414;
#   --core-color-border-primary: #e5e6e1;
#   --core-color-border-secondary: #a3a3a0;
#   --core-extension-color-content-accent: #b62682;
#   --core-extension-color-content-link: #145bc7;
#   --core-extension-color-content-positive: #1d7a24;
#   --core-extension-color-content-info: #141414;
#   --core-extension-color-content-warning: #ac5b06;
#   --core-extension-color-content-negative: #b81d29;
#   --core-extension-color-background-brand: #e1f56e;
#   --core-extension-color-background-brand-light: #edfca2;
#   --core-extension-color-background-accent: #b62682;
#   --core-extension-color-background-accent-light: #fff0f9;
#   --core-extension-color-background-positive: #0c990c;
#   --core-extension-color-background-positive-light: #ebfaeb;
#   --core-extension-color-background-info: #ebc11c;
#   --core-extension-color-background-info-light: #fff8db;
#   --core-extension-color-background-warning: #e07901;
#   --core-extension-color-background-warning-light: #fff3e5;
#   --core-extension-color-background-negative: #d62f2f;
#   --core-extension-color-background-negative-light: #fff0f0;
#   --core-extension-color-border-brand: #b1d004;
#   --core-extension-color-border-accent: #b62682;
#   --core-extension-color-border-positive: #0c990c;
#   --core-extension-color-border-info: #ebc11c;
#   --core-extension-color-border-warning: #e07901;
#   --core-extension-color-border-negative: #d62f2f;
#   --core-states-color-content-disabled: #a3a3a0;
#   --core-states-color-content-link-hover: #093a8f;
#   --core-states-color-content-link-active: #093a8f;
#   --core-states-color-content-link-visited: #660c51;
#   --core-states-color-content-accent-active: #660c51;
#   --core-states-color-background-hover: #f4f5f2;
#   --core-states-color-background-active: #e5e6e1;
#   --core-states-color-background-disabled: #f4f5f2;
#   --core-states-color-background-accent-hover: #8f156a;
#   --core-states-color-background-accent-active: #660c51;
# }
# .rs-button {
#   align-items: center;
#   border: solid 0.063rem;
#   border-radius: 0.125rem;
#   color: #141414;
#   cursor: pointer;
#   display: flex;
#   font-weight: bold;
#   justify-content: center;
#   line-height: 1.5rem;
#   padding: 0.5rem 1rem;
#   text-align: center;
#   transition: background-color 0.3s ease;
#   height: 2.5rem;
# }
# .rs-button_regular {
#   background-color: #e5e6e1;
#   border-color: #a3a3a0;
#   box-shadow: inset 0 -0.0625rem 0.0625rem 0 #a3a3a0, inset 0 0.0625rem 0.0625rem 0 #ffffff;
#   text-shadow: 0 0.0625rem 0 #ffffff;
# }
# .rs-button_regular:not([disabled]):hover {
#   background-color: #cbccc7;
# }
# .rs-button_regular:focus {
#   border-color: #b1d004;
#   border: 0.063rem solid #b1d004;
#   box-shadow: 0 0 0.25rem 0 #b1d004, inset 0 -0.063rem 0.063rem 0 #8e8f8c, inset 0 0.063rem 0.063rem 0 #ffffff;
#   border-radius: 0.125rem;
#   outline: none;
# }
# .rs-button_outline {
#   background-color: #fff;
#   border-color: #b62682;
#   box-shadow: inset 0 -0.0625rem 0.0625rem 0 #8f156a, inset 0 0.0625rem 0.0625rem 0 rgba(255, 255, 255, 0.5);
#   color: #b62682;
# }
# .rs-button_outline:not([disabled]):hover {
#   background-color: #8f156a;
#   color: #fff;
# }
# .rs-button_outline:focus {
#   border: 0.063rem solid #b1d004;
#   box-shadow: 0 0 0.25rem 0 #b1d004, inset 0 -0.063rem 0.063rem 0 #8f156a, inset 0 0.063rem 0.063rem 0 rgba(255, 255, 255, 0.2);
#   border-radius: 0.125rem;
#   outline: none;
# }
# .rs-button_action {
#   background-color: #b62682;
#   border-color: #b62682;
#   box-shadow: inset 0 -0.0625rem 0.0625rem 0 #8f156a, inset 0 0.0625rem 0.0625rem 0 rgba(255, 255, 255, 0.5);
#   color: #ffffff;
# }
# .rs-button_action:not([disabled]):hover {
#   background-color: #8f156a;
# }
# .rs-button_action:focus {
#   border: 0.063rem solid #b1d004;
#   box-shadow: 0 0 0.25rem 0 #b1d004, inset 0 -0.063rem 0.063rem 0 #8f156a, inset 0 0.063rem 0.063rem 0 rgba(255, 255, 255, 0.2);
#   border-radius: 0.125rem;
#   outline: none;
# }
# .rs-button_link {
#   background-color: transparent;
#   border-color: transparent;
#   box-shadow: none;
#   color: #145bc7;
#   font-weight: 400;
# }
# .rs-button_link:not([disabled]):hover {
#   text-decoration: underline;
#   background-color: transparent;
# }
# .rs-button_link:focus {
#   outline: thin dotted;
#   touch-action: manipulation;
#   padding: 0.5rem 1rem;
#   border-radius: 0.125rem;
# }
# .rs-button[disabled] {
#   cursor: inherit;
#   opacity: 0.64;
# }
# .sticky-container .rs-button {
#   width: 100%;
# }
# @media screen and (min-width: 62rem) {
#   .sticky-container .rs-button {
#     width: 12.5rem;
#   }
# }
# .rs-modal {
#   display: none;
# }
# .rs-modal:before {
#   background-color: rgba(0, 0, 0, 0.75);
#   bottom: 0;
#   content: "";
#   display: none;
#   left: 0;
#   position: fixed;
#   right: 0;
#   top: 0;
#   z-index: 10;
# }
# .rs-modal.opened {
#   display: block;
# }
# .rs-modal.opened::before {
#   display: block;
# }
# .rs-modal.opened .rs-modal-dialog {
#   max-height: 100vh;
#   background-color: #fff;
#   box-shadow: none;
#   border: #333333 solid 0;
#   border-radius: 2px;
#   position: fixed;
#   left: 0;
#   top: 0;
#   z-index: 11;
#   width: 100%;
#   overflow: auto;
# }
# @media screen and (min-width: 48rem) {
#   .rs-modal.opened .rs-modal-dialog {
#     box-shadow: 0 0.375rem 2.25rem 0 rgba(0, 0, 0, 0.6);
#     max-height: calc(100vh - (3.125rem * 2));
#     padding: 0;
#   }
# }
# .rs-modal.opened .rs-modal-dialog p {
#   margin-top: 0;
# }
# .rs-modal.opened .rs-modal-dialog-header {
#   align-items: flex-start;
#   display: flex;
#   padding: 1.5rem 1.5rem 1rem;
# }
# @media screen and (min-width: 48rem) {
#   .rs-modal.opened .rs-modal-dialog-header {
#     padding: 2rem 2rem 1.5rem;
#   }
# }
# .rs-modal.opened .rs-modal-dialog-header h2 {
#   flex-grow: 1;
#   font-weight: 700;
#   line-height: 1.5rem;
#   margin-bottom: 0;
#   margin-right: 1rem;
#   padding-top: 0;
# }
# .rs-modal.opened .rs-modal-dialog-header span {
#   font-size: 1.25rem;
# }
# .rs-modal.opened .rs-modal-dialog-header span:not(.svg-close) {
#   flex-grow: 1;
#   font-weight: 700;
#   margin-right: 1rem;
# }
# .rs-modal.opened .rs-modal-dialog-header .svg-close::before {
#   cursor: pointer;
#   background-position: center;
#   background-repeat: no-repeat;
#   width: 1.25rem;
#   height: 1.25rem;
#   content: '';
#   background-image: url(data:image/svg+xml;base64,...);
#   display: block;
# }
# .rs-modal.opened .rs-modal-dialog-content {
#   background-color: #fff;
#   padding: 0 1.5rem 1rem;
#   position: relative;
# }
# @media screen and (min-width: 48rem) {
#   .rs-modal.opened .rs-modal-dialog-content {
#     background-color: transparent;
#     padding: 0 2rem 1rem;
#   }
# }
# .rs-modal.opened .rs-modal-dialog-footer {
#   background-color: #fff;
#   padding: 0 1.5rem 1.5rem;
# }
# @media screen and (min-width: 48rem) {
#   .rs-modal.opened .rs-modal-dialog-footer {
#     background-color: transparent;
#     padding: 0 2rem 2rem;
#   }
# }
# @media screen and (min-width: 48rem) {
#   .rs-modal.opened .rs-modal-dialog-small {
#     margin-left: calc((100vw - 21.75rem)/2);
#     margin-right: calc((100vw - 21.75rem)/2);
#     margin-top: 3.125rem;
#     width: auto;
#   }
# }
# @media screen and (min-width: 62rem) {
#   .rs-modal.opened .rs-modal-dialog-small {
#     margin-left: calc((100vw - 22.5rem)/2);
#     margin-right: calc((100vw - 22.5rem)/2);
#   }
# }
# @media screen and (min-width: 48rem) {
#   .rs-modal.opened .rs-modal-dialog-medium {
#     margin-left: calc((100vw - 33.375rem)/2);
#     margin-right: calc((100vw - 33.375rem)/2);
#     margin-top: 3.125rem;
#     top: 0;
#     width: auto;
#     z-index: 11;
#   }
# }
# @media screen and (min-width: 62rem) {
#   .rs-modal.opened .rs-modal-dialog-medium {
#     margin-left: calc((100vw - 34.5rem)/2);
#     margin-right: calc((100vw - 34.5rem)/2);
#   }
# }
# @media screen and (min-width: 48rem) {
#   .rs-modal.opened .rs-modal-dialog-large {
#     margin-left: calc((100vw - 34.5rem)/2);
#     margin-right: calc((100vw - 34.5rem)/2);
#     margin-top: 3.125rem;
#     top: 0;
#     width: auto;
#     z-index: 11;
#   }
# }
# @media screen and (min-width: 62rem) {
#   .rs-modal.opened .rs-modal-dialog-large {
#     margin-left: calc((100vw - 46.5rem)/2);
#     margin-right: calc((100vw - 46.5rem)/2);
#   }
# }
# .modal-open {
#   overflow: hidden;
#   position: fixed;
#   width: 100%;
#   -webkit-overflow-scrolling: touch;
# }
# .rs-checkbox {
#   display: block;
#   margin-bottom: 1rem;
#   position: relative;
# }
# .rs-checkbox_label {
#   display: inline-flex;
#   margin-left: 1.75rem;
# }
# .rs-checkbox_label::before,
# .rs-checkbox_label_text {
#   cursor: pointer;
# }
# .rs-checkbox_label::before {
#   background-color: white;
#   border: solid 0.0625rem #6F6F6D;
#   box-sizing: border-box;
#   content: '';
#   display: inline-block;
#   height: 1.25rem;
#   left: 0;
#   position: absolute;
#   top: 0.125rem;
#   width: 1.25rem;
# }
# .rs-checkbox_label_text {
#   color: #141414;
#   font-size: 1rem;
# }
# .rs-checkbox_input {
#   opacity: 0;
#   position: absolute;
# }
# .rs-checkbox_input:focus + .rs-checkbox_label::before {
#   outline-style: dotted;
#   outline-width: 0.0625rem;
# }
# .rs-checkbox_input:checked + .rs-checkbox_label::before {
#   border-color: #b62682;
# }
# .rs-checkbox_input:checked + .rs-checkbox_label .rs-checkbox_label_text {
#   color: #b62682;
# }
# .rs-checkbox_input:checked + .rs-checkbox_label .rs-checkbox_label_text::before {
#   background-image: url(...);
#   background-position: center;
#   background-repeat: no-repeat;
#   content: '';
#   height: 1.25rem;
#   left: 0;
#   position: absolute;
#   top: 0.125rem;
#   width: 1.25rem;
# }
# .rs-checkbox_input:disabled + .rs-checkbox_label:before {
#   border: solid 0.0625rem #cbccc7;
# }
# .rs-checkbox_input:disabled + .rs-checkbox_label .rs-checkbox_label_text {
#   color: #A3A3A0;
# }
# .rs-checkbox.rs-feedback-error .rs-checkbox_label::before {
#   border: 0.0625rem solid #e07901;
# }
#
# </style><style>.rs-3d-container{width:100%}.rs-3d-container_frame{height:calc(100% - 11.0625rem);margin-top:7.0625rem;width:100%}@media screen and (min-width:36rem){.rs-3d-container_frame{height:100%;margin-top:0}}@media screen and (min-width:62rem){.rs-3d-container_frame{height:calc(100% - 7.0625rem);margin-top:0}.rs-3d-container.rs-3d-container-margin .rs-3d-container_frame{margin-top:4rem}}.rs-gallery-container:not(.contact-slide):not(.homestaging-slide):not(.map-slide):not(.plan) .image-gallery.full-percentage-height div{height:100%!important}.homestaging-container{align-items:center;display:flex;height:calc(100vh - 11rem);justify-content:center;margin-top:7rem}@media screen and (min-width:62rem){.homestaging-container .layer-bottom,.homestaging-container .rs-homestaging-image,.homestaging-container .rs-image-prop{height:100%;width:auto}.homestaging-container .layer-bottom>picture,.homestaging-container .rs-homestaging-image>picture,.homestaging-container .rs-image-prop>picture{height:100%;width:100%}.homestaging-container .layer-bottom>picture>img,.homestaging-container .rs-homestaging-image>picture>img,.homestaging-container .rs-image-prop>picture>img{height:100%;object-fit:contain;width:auto}}.rs-gallery-container .gallery-modal .map-container,.rs-gallery-container .image-gallery .item-gallery .map-container{height:calc(100vh - var(--dimension-x1600));height:calc(100dvh - var(--dimension-x1600));position:relative}@media screen and (min-width:62rem){.rs-gallery-container .gallery-modal .map-container,.rs-gallery-container .image-gallery .item-gallery .map-container{height:calc(100vh - 8rem);height:calc(100dvh - 8rem)}}.rs-gallery-container .gallery-modal .map-container,.rs-gallery-container .image-gallery .item-gallery .map-container,.rs-gallery-container .image-gallery .item-gallery .play-layer--map{display:flex;flex-direction:column;margin-left:0;margin-right:0;width:100%}.rs-gallery-container .gallery-modal .map-container .google-map,.rs-gallery-container .image-gallery .item-gallery .map-container .google-map,.rs-gallery-container .image-gallery .item-gallery .play-layer--map .google-map{height:100%;width:100%}.rs-gallery-container .gallery-modal .map-container .google-map.hidden,.rs-gallery-container .image-gallery .item-gallery .map-container .google-map.hidden,.rs-gallery-container .image-gallery .item-gallery .play-layer--map .google-map.hidden{display:none}.rs-gallery-container .gallery-modal .map-container .street-view,.rs-gallery-container .image-gallery .item-gallery .map-container .street-view,.rs-gallery-container .image-gallery .item-gallery .play-layer--map .street-view{height:100%;width:100%}.rs-gallery-container .gallery-modal .map-container .street-view.hidden,.rs-gallery-container .image-gallery .item-gallery .map-container .street-view.hidden,.rs-gallery-container .image-gallery .item-gallery .play-layer--map .street-view.hidden{display:none}.rs-gallery-container .gallery-modal .map-container .map-address-hidden,.rs-gallery-container .image-gallery .item-gallery .map-container .map-address-hidden,.rs-gallery-container .image-gallery .item-gallery .play-layer--map .map-address-hidden{background-color:var(--color-yellow-10);line-height:var(--dimension-x600);margin:0;padding:var(--dimension-x200);text-align:left;white-space:break-spaces}.rs-gallery-container .gallery-modal .map-container .map-address-hidden p:before,.rs-gallery-container .image-gallery .item-gallery .map-container .map-address-hidden p:before,.rs-gallery-container .image-gallery .item-gallery .play-layer--map .map-address-hidden p:before{color:var(--color-mono-100);display:inline-block;margin-bottom:var(--dimension-x100);margin-right:var(--dimension-x200)}.rs-gallery-container .gallery-modal .map-container .view-type-button,.rs-gallery-container .image-gallery .item-gallery .map-container .view-type-button,.rs-gallery-container .image-gallery .item-gallery .play-layer--map .view-type-button{align-items:center;background-color:var(--colo ...
#     #didomi-host {
#       font-family: 'bernino-regular', Arial, sans-serif;
#     }
#     #didomi-host a:not(.didomi-no-link-style) {
#       text-decoration: underline;
#       color: #666664 !important;
#
#       &:hover {
#         opacity: 0.7 !important;
#       }
#     }
#     #didomi-host :focus {
#     outline: none!important;
# }
#
#
# #didomi-host .didomi-consent-popup-preferences-vendors .didomi-consent-popup-body_vendors-list .didomi-vendors-details-title {
#   font-weight: 400;
# }
#
# #didomi-host .didomi-components-accordion .didomi-components-accordion-label-container .label-click {
#     margin-top: .5rem;
# }
#
# #didomi-host .didomi-consent-popup-vendor__description .didomi-components-accordion-label-container .trigger-icon + span {
#     flex-grow: 1;
# }
#
# #didomi-host .didomi-consent-popup-preferences-purposes .didomi-consent-popup-data-processing__purpose_actions {
#     flex-wrap: wrap;
#     justify-content: flex-start;
#     row-gap: .5rem;
# }
#
# #didomi-host .didomi-consent-popup-preferences .didomi-consent-popup-vendor .didomi-consent-popup-vendor__buttons {
#     margin-left: 40px;
# }
#
# #didomi-host .didomi-consent-popup-vendor__description .didomi-components-accordion-label-container {
#     text-decoration: none;
# }
#
# #didomi-host .didomi-consent-popup-preferences-purposes .vendors-count-label {
#     margin-right: 1rem;
# }
#
# #didomi-host .didomi-consent-popup-preferences .didomi-consent-popup-data-processing__buttons {
#     margin-left: 0;
# }
#
# #didomi-host {
#     z-index: 2147483001!important;
#
# }
#
# #didomi-host .didomi-notice-banner {
# 	border-top: solid .25rem #b1d004!important;
#
# }
#
# #didomi-host .didomi-regular-notice
# .multiple .didomi-button-highlight,
# #didomi-host .didomi-popup-footer .didomi-popup-actions .highlight-button {
# 	-webkit-appearance: none!important;
# 	appearance: none!important;
# 	background-color: #B62682!important;
# 	border-radius: .125rem!important;
# 	border: .0625rem solid #B62682!important;
# 	box-shadow: inset 0 -1px 1px 0 #8c1d64,inset 0 1px 1px 0 rgba(255,255,255,0.5)!important;
# 	box-sizing: border-box!important;
# 	color: #fff!important;
# 	cursor: pointer!important;
# 	display: inline-block!important;
# 	font-size: 0.9rem!important;
# 	font-weight: 700!important;
# 	min-height: 2.625rem!important;
# 	padding: .375rem 1rem!important;
# 	text-align: center!important;
# 	text-decoration: none!important;
# 	word-wrap: break-word!important;
#
# }
#
# #didomi-host .didomi-regular-notice p:last-child {
#     margin-bottom: 0;
# }
#
# #didomi-host #didomi-notice.didomi-regular-notice a {
#     color: #145bc7!important;
#     text-decoration: none;
# }
#
# #didomi-host .didomi-regular-notice
# .multiple .didomi-button-standard {
#     background-color: transparent!important;
# 	border-width: 0!important;
# 	color: #145BC7!important;
#     font-size: 0.9rem!important;
# 	font-weight: 700!important;
# 	padding-bottom: .5rem!important;
# 	padding-top: .5rem!important;
#
# }
#
# #didomi-host .didomi-notice-text {
#     color: #141414!important;
#     font-size: .875rem!important;
#     line-height: 1.25rem!important;
#     max-height: calc(40vh - 2.75rem)!important;
#     width: 100%!important;
#
# }
#
# ...
# 				{{picture.id}}
# 				Hemos enviado la foto a tus amigos/as
# 				{{:picture.id}}
# 				Hemos enviado el anuncio a tus amigos/as
# 				{{/picture.id}}
# 			</fieldset>
# 			{{/showMessage}}
#
# 			{{showFavAdded}}
# 				<p class="modal-share-form__paragraph">También hemos guardado el anuncio como favorito para tu comodidad</p>
# 			{{/showFavAdded}}
#
# 			{{showForm}}
# 			<fieldset class="modal-share-copy copy-url">
# 				<h3 class="modal-share-h3">Copiar enlace</h3>
# 				<span class="modal-share-copy-input copy-url__box">
# 					<input class="copy-url__box-text" type="text" readonly="readonly" value="https://www.idealista.com{{=locationPathname}}?utm_medium=socialmedia&utm_campaign=private_sendadtofriend&utm_source=copiedLink" />
# 					<span class="share-link clipboard-share icon-copy" data-txt-copied="Copiado">Copiar</span>
# 				</span>
# 			</fieldset>
# 			<fieldset class="modal-share-receiver">
# 				<h3 class="modal-share-h3">Compartir por email</h3>
# 				<span class="modal-share-feedback-error">No hemos podido enviar el anuncio, revisa si sigue activo y prueba de nuevo.</span>
# 				<label for="share-to-friend-to">Email de tus amigos</label>
# 				<input name="share-to-friend-to" id="share-to-friend-to" type="email" value=""
# 					   data-validation="required multiple_emails"
# 					   data-message-required="Dinos a quién se lo enviamos ;-)"
# 					   data-message-multiple_emails="Revisa el formato de los emails de tus amigos"
# 					   autofocus
# 				>
# 				<span class="modal-share-help-text">Si son varios sepáralos con una coma (,)</span>
# 			</fieldset>
# 			<fieldset class="modal-share-transmitter">
# 				<label for="share-to-friend-from" class="transmitter-label">Tu email</label>
# 				<input name="contact-email" id="share-to-friend-from" value="" type="email"
# 					   autocomplete="email"
# 					   data-validation="required email"
# 					   data-message-required="Indica tu email"
# 					   data-message-email="Revisa el formato de tu email"
# 				>
# 				<span class="modal-share-help-text transmitter-help-text">
# 					{{picture.id}}
# 						Quien recibe la foto lo verá
# 					{{:picture.id}}
# 						Quien recibe el anuncio lo verá
# 					{{/picture.id}}
# 				</span>
# 				<a class="message-link icon-plus" href="">Añadir mensaje</a>
# 				<span class="modal-share-message">
# 					<label class="message-label" for="share-to-friend-message">Tu mensaje</label>
# 					<textarea class="message-textarea" rows="2" name="contact-message" maxlength="1000" id="share-to-friend-message"></textarea>
# 				</span>
# 			</fieldset>
# 			<fieldset class="modal-share-submit">
# 				<input class="btn action" value='Enviar' type="submit" id="share-friend-send" disabled/>
# 			</fieldset>
#
# 			<input type="hidden" id="adId" name="share-to-friend-adId" value="103344400" />
# 			<input type="hidden" id="cookieEnabled" name="cookieEnabled" value="true" />
#
#
# 			<div class="d-none">
# 				<input type="text" value="" name="contact-mail">
# 			</div>
# 			{{:showForm}}
# 				<fieldset class="modal-share-feedback-buttons">
# 					{{picture.id}}
# 					<a href="" data-xiti-shared-n2="true" data-xiti-page="detalle::conversiones::form_compartir_foto" title="Compartir con más gente" class="anotherTime btn regular modal-share-with-others-button">Compartir con más gente</a>
# 					{{:picture.id}}
# 					<a href="" data-xiti-shared-n2="true" data-xiti-page="detalle::conversiones::form_compartir" title="Compartir con más gente" class="anotherTime btn regular modal-share-with-others-button">Compartir con más gente</a>
# 					{{/picture.id}}
# 					<a href="#" class="modal-share-close-button cancel">Cerrar</a>
# 					{{/showForm}}
# 				</fieldset>
# 		</form>
# 	</section>
#
# </script>
# <script id="notify-incidence-step1" type="text/microtemplate">
#
# 		<div class="modal-inner">
# 			<form action="" method="post" id="ferror" name="ferror">
#
# 				<div class="item-form help-us-modal">
# 					<p>
# 						Anuncio:Ático en venta en paseo de l'Albereda
# 					</p>
# 					<p class="icon-feedbk-info">
# 						Esta información llega al equipo de calidad de idealista y al anunciante, pero él no conocerá tu identidad
# 					</p>
# 					<ul data-validation="radio" data-message-radio="Por favor selecciona una de las opciones que mejor describa el tipo de error que has visto">
#
#
# 							<li>
# 								<label class="input-radio">
#
#
#
#
#
#
# 									<input type="radio" id="iTipoComentario7" name="incidenceTypeId" value="7" />
# 									<span><span>La dirección está mal</span></span>
# 								</label>
# 							</li>
#
# 							<li>
# 								<label class="input-radio">
#
#
#
#
#
#
# 									<input type="radio" id="iTipoComentario6" name="incidenceTypeId" value="6" />
# 									<span><span>El precio no es correcto</span></span>
# 								</label>
# 							</li>
#
# 							<li>
# 								<label class="input-radio">
#
#
#
#
#
#
# 									<input type="radio" id="iTipoComentario11" name="incidenceTypeId" value="11" />
# 									<span><span>Es una posible estafa</span></span>
# 								</label>
# 							</li>
#
# 							<li>
# 								<label class="input-radio">
#
#
#
#
#
#
# 									<input type="radio" id="iTipoComentario13" name="incidenceTypeId" value="13" />
# 									<span><span>Comentarios discriminatorios y/u ofensivos</span></span>
# 								</label>
# 							</li>
#
# 							<li>
# 								<label class="input-radio">
#
#
#
#
#
#
# 									<input type="radio" id="iTipoComentario1" name="incidenceTypeId" value="1" />
# 									<span><span>Error en las fotos</span></span>
# 								</label>
# 							</li>
#
# 							<li>
# 								<label class="input-radio">
#
#
#
#
#
#
# 									<input type="radio" id="iTipoComentario8" name="incidenceTypeId" value="8" />
# 									<span><span>El teléfono es erróneo o no lo cogen</span></span>
# 								</label>
# 							</li>
#
# 							<li>
# 								<label class="input-radio">
#
#
#
#
#
#
# 									<input type="radio" id="iTipoComentario9" name="incidenceTypeId" value="9" />
# 									<span><span>El email es erróneo o el anunciante no responde</span></span>
# 								</label>
# 							</li>
#
# 							<li>
# 								<label class="input-radio">
#
#
#
#
#
#
# 									<input type="radio" id="iTipoComentario3" name="incidenceTypeId" value="3" />
# 									<span><span>Ya está vendido</span></span>
# 								</label>
# 							</li>
#
# 							<li>
# 								<label class="input-radio">
#
#
#
#
#
#
# 									<input type="radio" id="iTipoComentario5" name="incidenceTypeId" value="5" />
# 									<span><span>Otro motivo</span></span>
# 								</label>
# 							</li>
#
# 					</ul>
# 				</div>
#
# 				<div class="item-form">
# 					<label>
# 						<span>Descripción completa del error (opcional)</span>
# 						<textarea  name="comments" maxlength="1000" id="ferror-text" placeholder="Este texto también le llegará al anunciante" data-message-required="Por favor, describe el error o errores que has visto"></textarea>
# 						<span id="comment" class="help-text block v-hidden">Este texto también le llegará al anunciante</span>
# 					</label>
# 				</div>
#
# 				<a href="#" class="btn action" id="submitBtn">Enviar error</a>
# 			</form>
# 		</div>
#
# </script>
# <script id="notify-incidence-step2" type="text/microtemplate">
#
# 		<div class="modal-inner modal-improve-feedback">
# 			<form action="" id="ferror2" method="post" >
# 				<input type="hidden" name="incidenceId" id="incidenceId" value="" />
#
# 				<div class="feedback success icon-feedbk-ok" id="feedback-success-div">
# 					<p>
# 						Gracias por ayudarnos a mejorar idealista :-) <br> Te avisaremos cuando esté aclarado
# 					</p>
# 				</div>
#
# 				<div class="item-form">
# 					<h3>
# 						¿Quieres que te avisemos cuando se solucione?
# 					</h3>
# 					<p>
# 						Indícanos tus datos (no los recibirá el anunciante)
# 					</p>
# 				</div>
#
# 				<div class="item-form-and-half">
# 					<label for="incidence-user-name">
# 						Tu nombre y apellidos
# 					</label>
# 					<input name="name" id="incidence-user-name" value="" type="text"
# 						data-validation="required"
# 						data-message-required="Requerido">
# 				</div>
#
# 				<div class="item-form-and-half">
# 					<label for="incidence-user-email">
# 						Tu email
# 					</label>
# 					<input name="mail" id="incidence-user-email" value="" type="email"
# 						autocomplete="email"
# 						data-validation="required email"
# 						data-message-required="Requerido"
# 						data-message-email="No es un mail válido">
# 				</div>
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="item-form privacy-policy-container">
#
#         <label class="input-checkbox" data-validation="checkbox" data-message-checkbox="Para contactar debes aceptar la política de privacidad" data-error-name="privacy-policy-checkbox">
#             <input type="checkbox" name="privacy-policy-checkbox"/>
#             <span>
#             <span>
#                 Aceptar
#                 <a href="https://www.idealista.com/ayuda/articulos/politica-de-privacidad/" target="_blank">política de privacidad</a>
#             </span>
#         </span>
#         </label>
#
#
# </div>
#
# 				<a href="#" class="btn action" id="submitBtn">
# 					Enviar
# 				</a>
# 				<a href="#" id="cancelBtn">
# 					No, gracias
# 				</a>
# 			</form>
# 		</div>
#
# </script>
# <script id="notify-incidence-step3" type="text/microtemplate">
#
# 	<div class="modal-inner incidence-feedback">
# 		<div class="help-us-modal feedback success icon-feedbk-ok" id="user-added-success-div">
# 			<p>
# 				Gracias por ayudarnos a mejorar idealista :-)
# 				<br />
# 				Te avisaremos cuando esté aclarado
# 			</p>
# 		</div>
#
# 		<a href="#" class="btn action" id="closeBtn">
# 			Cerrar
# 		</a>
# 	</div>
#
# </script>
# <script id="show-more-photos-tmpl" type="text/microtemplate">
#
# 		<div class="button overlay-box">
# 			<a class="btn regular more-photos" data-markup="seePhotos">
# 				{{=label}}
# 			</a>
# 		</div>
#
# </script>
# <script id="saving-alert-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
# {{lessSavingAlert}}
# 	Necesitas cubrir la aportación mínima que piden los bancos. <a id="link-set-saving" href="" data-markup='detalle::mortgages::savings-adjust'>Ajustar</a>.
# {{/lessSavingAlert}}
#
# {{bigSavingWarning}}
# 	El ahorro aportado no puede ser mayor o igual que el precio del inmueble
# {{/bigSavingWarning}}
#
# </script>
# <script id="saving-warning-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# El ahorro aportado no puede ser mayor o igual que el precio del inmueble
#
# </script>
# <script id="minmortgages-alert-tmpl" type="text/microtemplate">
#
#     <div class="feedback contextual full-width neutral-temp icon-feedbk-info">
#
#
#
#
#
#
#
#
#
#
#
#
# Los bancos no suelen dar hipotecas si el importe de esta es inferior a {{=minMortgages}}€
#
#     </div>
#
# </script>
# <script id="minhouseprice-alert-tmpl" type="text/microtemplate">
#
#     <div class="feedback contextual full-width neutral-temp icon-feedbk-info">
#
#
#
#
#
#
#
#
#
#
#
#
# Los bancos no suelen dar hipotecas para viviendas inferiores a {{=minHousePrice}}€
#
#     </div>
# </script>
# <script id="rate-type-info-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="mortgages-modal-content-container">
# 	<h3 class="txt-medium txt-bold mb-small">¿Cómo hemos calculado el interés?</h3>
# 	<p>Este tipo de interés es una referencia media del mercado hipotecario.</p>
# 	<p><strong>Fijo: </strong>es el tipo de interés que se mantiene constante durante toda la vida del préstamo. Es más bajo cuando menor sea el plazo.</p>
# 	<p><strong>Variable: </strong>la cuota variará a lo largo de la vida del préstamo en función a las fluctuaciones del euribor</p>
# </div>
#
# </script>
# <script id="savings-info-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="mortgages-modal-content-container">
# 	<p></p>
# </div>
#
# </script>
# <script id="contact-modal-loader-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
# <article class="step-layout" style="min-width: 552px; min-height: 599px;">
# 	<div class="form-wrapper">
# 		<header class="idform-header">
# 			<span class="icon-idealista-icon"></span>
# 			<span class="icon-hipotecas"></span>
# 		</header>
# 		<div class="step-layout__content">
#
# 		</div>
# 	</div>
# </article>
# </script>
# <script id="comment-translation-tmpl" type="text/microtemplate">
#
#         <div class="translationWarning">
#             <span>{{=message}}</span>
#             <span class="viewOriginalComment"><a href="#" data-lang="es">{{=messageLink}}</a></span>
#         </div>
#
# </script>
# <script id="expander-button-tmpl" type="text/microtemplate">
#
#             <div class="expanderParent">
#                 <span class="icon-arrow-right"></span>
#                 <a href="#" class="expander">Leer comentario completo</a>
#             </div>
#
# </script>
# <script id="formatted-phone" type="text/microtemplate">
#     <a role="button"
#        class="icon-phone hidden-contact-phones_formatted-phone _mobilePhone"
#        href="tel:{{=phoneNumber}}">
#         <span class="hidden-contact-phones_text">{{=formattedPhoneNumber}}</span>
#         <span tabindex="0" class="phone-type-info phone-type-info--hidden"></span>
#     </a>
# </script>
# <script id="auction-valuation-info" type="text/microtemplate">
#     <p class="auction-valuation-title">Estimación del precio de mercado</p>
#     <article class="auction-valuation-article">
#         <p class="auction-valuation-price">{{=priceValuationFeatures.average}}</p>
#         <div class="auction-valuation-range-container">
#             <span class="auction-valuation-range">min. {{=priceValuationFeatures.min}}</span>
#             <span class="auction-valuation-range_line"></span>
#             <span class="auction-valuation-range">max. {{=priceValuationFeatures.max}}</span>
#         </div>
#     </article>
#     <span role="button" id="price-valuation-info" class="auction-valuation-info">
#         <span class="auction-valuation-info-text">¿Cómo calculamos la valoración?</span>
#         <span class="icon-feedbk-info"></span>
#     </span>
# </script>
# <script id="agency-branding" type="text/microtemplate">
#     <h2 class="ide-box-detail-h2">
#         Información y servicios de Engel & Völkers València
#     </h2>
#
#
#
#
#
#
#
#
#
#     <img src="https://st3.idealista.com/37/c6/5f/engelvalencia.gif"
#          class="agency-video__logo"
#          data-ondemand-img="https://st3.idealista.com/37/c6/5f/engelvalencia.gif"
#          alt="Engel & Völkers València"/>
#     {{agencyBrandingFeatures.showCorporateVideo}}
#         <section class="agency-video-trigger">
#             <figure class="agency-video__figure"
#                     aria-role="button"
#                     aria-label="Play agency video">
#                 <div style="background-image: url('{{=agencyBrandingFeatures.thumbnailUrl}}');"
#                      class="agency-video__background"></div>
#                 <img class="agency-video__image" src="{{=agencyBrandingFeatures.thumbnailUrl}}" />
#                 <span class="agency-video__play"></span>
#             </figure>
#         </section>
#     {{/agencyBrandingFeatures.showCorporateVideo}}
#     {{agencyBrandingFeatures.showCorporatePhrase}}
#         {{agencyBrandingFeatures.isAutoTranslated}}
#             <div class="translationWarning">
#                 <p class="agency-branding-container__description">{{=agencyBrandingFeatures.corporatePhrase.text}}</p>
#                 <span>Esta descripción ha sido traducida automáticamente y puede que no sea muy precisa.</span>
#             </div>
#         {{:agencyBrandingFeatures.isAutoTranslated}}
#             <p class="agency-branding-container__description">{{=agencyBrandingFeatures.corporatePhrase.text}}</p>
#         {{/agencyBrandingFeatures.isAutoTranslated}}
#     {{/agencyBrandingFeatures.showCorporatePhrase}}
# </script>
# <script src="https://st3.idealista.com/static/react/projects/detail/dist/detail.21a7493a39f74d1e5466.js"></script></body></html>

# %% [markdown]
# Perfecto, ya podemos empezar a sacarle los datos.
#
# Realizamos lo mismo que aparece en el vídeo.

# %%
titulo = soup.find('span',{'class':'main-info__title-main'}).text
titulo
# Out:
# "Ático en venta en paseo de l'Albereda"

# %%
localizacion = soup.find('span',{'class':'main-info__title-minor'}).text.split(',')[0]
localizacion
# Out:
# 'Mestalla'

# %%
precio = int(soup.find('span',{'class':'txt-bold'}).text.replace('.',''))
precio
# Out:
# 8600000

# %%
c1 = soup.find('div',{'class':'details-property'}).find('div',{'class': 'details-property-feature-one'})
c1
# Out:
# <div class="details-property-feature-one">
# <h2 class="details-property-h2">Características básicas</h2>
# <div class="details-property_features">
# <ul>
# <li>680 m² construidos</li>
# <li>5 habitaciones</li>
# <li>6 baños</li>
# <li>Terraza</li>
# <li>Plaza de garaje incluida en el precio</li>
# <li>Segunda mano/buen estado</li>
# <li>Armarios empotrados</li>
# <li>Construido en 1992</li>
# <li>Calefacción central: Gas</li>
# </ul>
# </div>
# <h2 class="details-property-h2">Edificio</h2>
# <div class="details-property_features">
# <ul>
# <li> exterior</li>
# <li>Con ascensor</li>
# </ul>
# </div>
# </div>

# %%
caract_basicas = [caract.text.strip() for caract in c1.find_all('li')]
caract_basicas
# Out:
# ['680 m² construidos',
#  '5 habitaciones',
#  '6 baños',
#  'Terraza',
#  'Plaza de garaje incluida en el precio',
#  'Segunda mano/buen estado',
#  'Armarios empotrados',
#  'Construido en 1992',
#  'Calefacción central: Gas',
#  'exterior',
#  'Con ascensor']

# %%
c2 = soup.find('div',{'class':'details-property'}).find('div',{'class': 'details-property-feature-two'})
c2
# Out:
# <div class="details-property-feature-two">
# <h2 class="details-property-h2">Equipamiento</h2>
# <div class="details-property_features">
# <ul>
# <li>
# Aire acondicionado
# </li>
# <li>
# Piscina
# </li>
# </ul>
# </div>
# <h2 class="details-property-h2">Certificado energético</h2>
# <div class="details-property_features">
# <ul>
# <li>
# <span>Consumo: </span>
# <span class="icon-energy-c-e">146 kWh/m² año</span>
# </li>
# <li>
# <span>Emisiones: </span>
# <span class="icon-energy-c-e">29 kg CO2/m² año</span>
# </li>
# <div class="energy-certificate-dropdown">
# <a class="energy-certificate-open-link" data-click="1" data-markup="A|ceeLabelShow" href="">Ver etiqueta de calificación energética</a>
# <a class="energy-certificate-close-link" data-click="1" data-markup="A|ceeLabelHide" href="">Ocultar etiqueta</a>
# <figure class="energy-certificate-img-container">
# <span class="energy-certificate-img-ticket-left left-e" data-value-left-cee="146.0"></span>
# <span class="energy-certificate-img-ticket-right right-e" data-value-right-cee="29.0"></span>
# <img alt="idealista CEE" class="energy-certificate-img" src="https://st3.idealista.com/static/common/release/detail/resources/img/cee/es.svg?20241129-1307"/>
# </figure>
# </div>
# </ul>
# </div>
# </div>

# %%
caract_extra = [caract.text.strip() for caract in c2.find_all('li')]
caract_extra
# Out:
# ['Aire acondicionado',
#  'Piscina',
#  'Consumo: \n146 kWh/m² año',
#  'Emisiones: \n29 kg CO2/m² año']

# %%
ubicacion = soup.find('div',{'id':'headerMap'})
ubicacion
# Out:
# <div class="clearfix" id="headerMap">
# <h2 class="ide-box-detail-h2">Ubicación</h2>
# <ul>
# <li class="header-map-list">
# Paseo de l'Albereda
# </li>
# <li class="header-map-list">
# Barrio Mestalla
# </li>
# <li class="header-map-list">
# Distrito El Pla del Real
# </li>
# <li class="header-map-list">
# València
# </li>
# <li class="header-map-list">
# Valencia, València
# </li>
# </ul>
# </div>

# %%
ubicacion_desg = [zona.text.strip() for zona in ubicacion.find_all('li')]
ubicacion_desg
# Out:
# ["Paseo de l'Albereda",
#  'Barrio Mestalla',
#  'Distrito El Pla del Real',
#  'València',
#  'Valencia, València']

# %% [markdown]
# Vale, ya hemos sacado todos los datos que queremos!
#
# Lo bueno es, que, si quieres, puedes sacar los datos que tú quieras.

# %% [markdown]
# Vamos a automatizar esto para las casas de tu zona.

# %%
url_grande = 'https://www.idealista.com/venta-viviendas/valencia-valencia/'

# %% [markdown]
# Bueno sí, sigue siendo mi zona. Pero pon la tuya!

# %% [markdown]
# Ahora, queremos sacar el id de cada casa. Vamos a sacar el html de la pagina grande:

# %%
browser.get(url_grande)

# %%
browser.find_element("xpath",'//*[@id="didomi-notice-agree-button"]').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 browser.find_element("xpath",'//*[@id="didomi-notice-agree-button"]').click()
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:770, in WebDriver.find_element(self, by, value)
#     767         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     768     return elements[0]
# --> 770 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:384, in WebDriver.execute(self, driver_command, params)
#     382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
# --> 384     self.error_handler.check_response(response)
#     385     response["value"] = self._unwrap_value(response.get("value", None))
#     386     return response
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="didomi-notice-agree-button"]"}
#   (Session info: chrome=131.0.6778.86); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x006533E3+25059]
# 	(No symbol) [0x005DCDE4]
# 	(No symbol) [0x004BBEC3]
# 	(No symbol) [0x004FFD86]
# 	(No symbol) [0x004FFFCB]
# 	(No symbol) [0x0053D952]
# 	(No symbol) [0x00521F44]
# 	(No symbol) [0x0053B51E]
# 	(No symbol) [0x00521C96]
# 	(No symbol) [0x004F3FAC]
# 	(No symbol) [0x004F4F3D]
# 	GetHandleVerifier [0x00945543+3113795]
# 	GetHandleVerifier [0x0095A20A+3198986]
# 	GetHandleVerifier [0x009529E2+3168226]
# 	GetHandleVerifier [0x006F3250+680016]
# 	(No symbol) [0x005E572D]
# 	(No symbol) [0x005E29D8]
# 	(No symbol) [0x005E2B75]
# 	(No symbol) [0x005D57D0]
# 	BaseThreadInitThunk [0x767B5D49+25]
# 	RtlInitializeExceptionChain [0x77BFCEBB+107]
# 	RtlGetAppContainerNamedObjectPath [0x77BFCE41+561]

# %%
html = browser.page_source

# %%
soup = bs(html, 'lxml')
soup
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 soup = bs(html, 'lxml')
#       2 soup
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1465, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1507, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1308, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1945, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\debugpy\_vendored\pydevd\pydevd.py:2185, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2182             from_this_thread.append(frame_custom_thread_id)
#    2184     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2185         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2187 frames_list = None
#    2189 if keep_suspended:
#    2190     # This means that we should pause again after a set next statement.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\debugpy\_vendored\pydevd\pydevd.py:2254, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2251                 queue.put(internal_cmd)
#    2252                 wait_timeout = TIMEOUT_FAST
# -> 2254         notify_event.wait(wait_timeout)
#    2255         notify_event.clear()
#    2257 finally:
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\threading.py:659, in Event.wait(self, timeout)
#     657 signaled = self._flag
#     658 if not signaled:
# --> 659     signaled = self._cond.wait(timeout)
#     660 return signaled
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# Ahora localizamos donde está cada casa y las listamos:

# %%
articles = soup.find('main',{'class':'listing-items'}).find_all('article')
articles

# %% [markdown]
# Seleccionemos los ids!

# %%
id_muebles = [article.get('data-adid') for article in articles]
id_muebles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 id_muebles = [article.get('data-adid') for article in articles]
#       2 id_muebles
#
# NameError: name 'articles' is not defined

# %% [markdown]
# Filtramos los nones:

# %%
id_muebles = [muebles for muebles in id_muebles if muebles is not None]
id_muebles

# %% [markdown]
# Ahora que tenemos los ids de **una**, toca repetir este proceso para cada página de nuestra zona. Este proceso lo explico muy bien en el video.

# %%
busqueda = 'los remedios'

busqueda = busqueda.replace(' ','-')

x=1
ids = []

while True:
    
    url = f'https://www.idealista.com/venta-viviendas/sevilla/{busqueda}/pagina-{x}.htm'
    
    browser.get(url)
    
    time.sleep(random.randint(10,12))
    
    try:
        
        browser.find_element("xpath",'//*[@id="didomi-notice-agree-button"]').click()
    except:
        pass
    
    html = browser.page_source
    
    soup = bs(html, 'lxml')
    
    pagina_actual = int(soup.find('main',{'class':'listing-items'}).find('div',{'class':'pagination'}).find('li',{'class':'selected'}).text)
    
    if x == pagina_actual:

        articles = soup.find('main',{'class':'listing-items'}).find_all('article')

    else:
        break
    
    x = x+1
    
    for article in articles:
        
        id_muebles = article.get('data-adid')
        
        ids.append(id_muebles)
        
        time.sleep(random.randint(1,3))
        print(id_muebles)
    
    ids = [muebles for muebles in ids if muebles is not None]

# %%
ids_casas = pd.DataFrame(ids)
ids_casas.columns = ['id']
ids_casas

# %% [markdown]
# Olé! Vamos a guardar estos ids para no perderlos.
#
# Lo gradaremos en un csv.
#
# Ojo al truqui de index= False!

# %%
ids_casas.to_csv('ids_casas.csv',index = False)

# %% [markdown]
# Ahora vamos a usar una técina muy utilizada en programación: crear algo vacío e ir rellenandolo.
#
# En este caso, creamos una serie llamada **casas** a la que vamos a ir añadiendo los datos scrapeados.
#
# Esta serie la pasamos a dataframe y vamos concatenandolas.

# %%
casas = pd.Series()

# %% [markdown]
# Aquí tienes la función. He dejado algunos prints comentados, descoméntalos si quieres verlos mientras scrapeamos.

# %%
def parsear_inmueble(id_inmueble):
    
    print( '\n Casa numero: ' + id_inmueble)
    
    url = "https://www.idealista.com/inmueble/" + id_inmueble + "/"
    
    browser.get(url)

    html = browser.page_source
    
    soup = bs(html, 'lxml')

    titulo = soup.find('span',{'class':'main-info__title-main'}).text
    
    print('\n Titulo: ' + titulo)
    
    localizacion = soup.find('span',{'class':'main-info__title-minor'}).text.split(',')[0]

    print('\n Localizacion: ' + localizacion)
    precio = int(soup.find('span',{'class':'txt-bold'}).text.replace('.',''))

    c1 = soup.find('div',{'class':'details-property'}).find('div',{'class': 'details-property-feature-one'})

    caract_basicas = [caract.text.strip() for caract in c1.find_all('li')]
    
    #print('Caracteristicas basicas:' + caract_basicas)

    c2 = soup.find('div',{'class':'details-property'}).find('div',{'class': 'details-property-feature-two'})

    caract_extra = [caract.text.strip() for caract in c2.find_all('li')]
    
    #print('Caracteristicas extras:' + caract_extra)
    
    casas['titulo'] = titulo
    
    casas['localizacion'] = localizacion
    
    casas['precio'] = precio
    
    casas['caracteristicas_basicas'] = caract_basicas
    
    casas['caracteristicas_extras'] = caract_extra
    
    df_casas = pd.DataFrame(casas)
    
    return(df_casas.T)

# %%
df_casas = parsear_inmueble(ids_casas.iloc[0].id)

for i in range(1,len(ids)):
    
    df_casas = pd.concat([df_casas,parsear_inmueble(ids[i])])
    
    time.sleep(random.randint(4,8))

# %% [markdown]
# A ver si funciona...

# %%
df_casas

# %% [markdown]
# Perfecto! reseteemos el índice y guardemos estos datos en otro csv.

# %%
df_casas.reset_index(drop=True, inplace=True)

# %%
df_casas

# %%
df_casas.to_csv('casas_idealista.csv', index = False, sep = ';', encoding = 'utf-16')
